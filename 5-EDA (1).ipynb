# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Data Science\Assignments\EDA1\Cardiotocographic.csv')

# %%
data.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
data['DS'] = data['DS'].round(decimals=6)  # Adjust the decimals based on your precision needs

# %%
data['DS'].unique()
# Out:
# array([ 0.000e+00, -2.000e-06,  4.000e-06,        nan, -3.000e-06,
#         3.000e-06,  1.000e-06,  6.000e-06, -1.000e-06, -5.000e-06,
#        -4.000e-06,  2.706e-03,  5.000e-06, -1.353e-03,  2.000e-06,
#        -7.000e-06,  8.900e-04,  1.079e-03,  2.704e-03,  9.480e-04,
#         1.178e-03,  1.144e-03,  1.353e-03])

# %%
all_zero = (data['DS'] == 0).all()
print("All values are zero:", all_zero)
# Out:
# All values are zero: False

# %%
non_zero_values = data[data['DS'] != 0]['DS']
print(non_zero_values)
# Out:
# 33     -0.000002
# 38      0.000004
# 50           NaN
# 69     -0.000003
# 84      0.000003
#           ...
# 2053   -0.000004
# 2075   -0.001353
# 2080   -0.000002
# 2088   -0.000001
# 2112    0.000001
# Name: DS, Length: 122, dtype: float64

# %%
miss = data.isnull().sum()
miss
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
for col in data.columns :
    if data[col].dtype in ['float64'] :
        data[col] = data[col].fillna(data[col].median())  # Filling the Missing Values

# %%
for col in data.columns :
    fig = plt.figure(figsize = [4,4])
    sns.boxplot(x = data[col])
    plt.show()

# %%
data.describe().T
# Out:
#            count        mean        std         min         25%         50%  \
# LB        2126.0  133.340204  11.214379   51.842487  126.000000  133.000000
# AC        2126.0    0.003204   0.004373   -0.019284    0.000000    0.001634
# FM        2126.0    0.009894   0.067540   -0.480634    0.000000    0.000000
# UC        2126.0    0.004391   0.003340   -0.014925    0.001851    0.004484
# DL        2126.0    0.001895   0.003343   -0.015393    0.000000    0.000000
# DS        2126.0    0.000002   0.000141   -0.001353    0.000000    0.000000
# DP        2126.0    0.000173   0.000836   -0.005348    0.000000    0.000000
# ASTV      2126.0   46.995984  18.813973  -63.000000   32.000000   49.000000
# MSTV      2126.0    1.364378   1.173632   -6.600000    0.700000    1.200000
# ALTV      2126.0   10.285964  21.205041  -91.000000    0.000000    0.000000
# MLTV      2126.0    8.276147   7.734851  -50.700000    4.600000    7.400000
# ...

# %%
data.median()
# Out:
# LB          133.000000
# AC            0.001634
# FM            0.000000
# UC            0.004484
# DL            0.000000
# DS            0.000000
# DP            0.000000
# ASTV         49.000000
# MSTV          1.200000
# ALTV          0.000000
# MLTV          7.400000
# Width        67.000000
# Tendency      0.000000
# NSP           1.000000
# dtype: float64

# %%
for col in data.columns :
    q1=data[col].quantile(0.25)
    q3=data[col].quantile(0.75)
    IQR = q3 - q1
    print(f"IQR of {col} : {IQR}")
# Out:
# IQR of LB : 14.0
# IQR of AC : 0.0056061275
# IQR of FM : 0.00256657125
# IQR of UC : 0.004685357249999999
# IQR of DL : 0.003289474
# IQR of DS : 0.0
# IQR of DP : 0.0
# IQR of ASTV : 29.0
# IQR of MSTV : 1.0
# IQR of ALTV : 11.0
# IQR of MLTV : 6.200000000000001
# IQR of Width : 63.0
# IQR of Tendency : 1.0
# IQR of NSP : 0.0

# %%
for col in data.columns :
    fig = plt.figure(figsize = [4,4])
    sns.histplot(x = col,data = data )
    plt.show()

# %%
data.nunique()
# Out:
# LB           153
# AC          1068
# FM           776
# UC          1364
# DL           822
# DS            22
# DP           264
# ASTV         183
# MSTV         165
# ALTV         195
# MLTV         351
# Width        261
# Tendency     111
# NSP          111
# dtype: int64

# %%
for col in data.columns :
    fig = plt.figure(figsize = [14,4])
    sns.countplot(x = col,data = data ) 
    plt.show()

# %%
for column in data.columns :
    fig = plt.figure(figsize = [4,4])
    sns.scatterplot(x = 'LB' ,y = column,data = data )
    plt.show()

# %%
sns.pairplot(data)

# %%
data.shape
# Out:
# (2126, 14)

# %%
correlation = data.corr()
plt.figure(figsize = [10,7])
sns.heatmap(correlation , annot = True,fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# ### 1.Strong Correlations (Absolute value ≥ 0.4)
#
# DL and MSTV : Correlation = 0.41\n
# DP (Decelerations Prolonged) and ASTV (Abnormal Short-Term Variability): Correlation = 0.42
# ASTV (Abnormal Short-Term Variability) and NSP (Target variable): Correlation = -0.42
# MSTV (Mean Short-Term Variability) and NSP: Correlation = -0.44
# DS (Decelerations Short) and DP (Decelerations Prolonged): Correlation = 0.41
#
# ### 2. Negative Correlations (Potential Risk Indicators)
#
# AC (Accelerations) and NSP: Correlation = -0.32
# ALTV (Abnormal Long-Term Variability) and NSP: Correlation = -0.37
#
# ### Weak or No Correlations
# Variables like FM (Fetal Movements) and UC (Uterine Contractions) have weak or near-zero correlations with NSP.S
